# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
## For first time, unzip object_detection folder to Tf2 folder
# !unzip '/content/gdrive/MyDrive/Tf2/object_detection.zip' -d '/content/gdrive/MyDrive/Tf2/'

# %%
import tensorflow as tf

tf.compat.v1.disable_eager_execution()

# %% [markdown]
# # Install Libraries

# %%
# !pip install tf-models-official &> /dev/null
# !pip install tf_slim &> /dev/null
# !pip install lvis &> /dev/null
# &> /dev/null to hide output

# %%
# %cd '/content/gdrive/MyDrive/Tf2/object_detection'
# Out:
# /content/gdrive/MyDrive/Tf2/object_detection

# %%
# !protoc protos/*.proto --python_out=. &> /dev/null

# %% [markdown]
# # Train Model

# %%
# !python model_main_tf2.py --pipeline_config_path=training_mnet/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.config --model_dir=training_mnet --alsologtostderr
# Out:
# 2021-03-01 07:57:31.771835: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-01 07:57:34.390620: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-01 07:57:34.391507: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-01 07:57:34.423049: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-01 07:57:34.423695: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %% [markdown]
# # Generate inference graph

# %%
# !python exporter_main_v2.py --trained_checkpoint_dir=training_mnet --pipeline_config_path=training_mnet/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.config --output_directory inference_graph_mnet
# Out:
# 2021-03-01 08:27:42.057385: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-01 08:27:45.004293: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-01 08:27:45.006493: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-01 08:27:45.037670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-01 08:27:45.038254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %% [markdown]
# # Evaluate Model

# %%
# !python model_main_tf2.py --pipeline_config_path=training_mnet/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.config  --model_dir=training_mnet --alsologtostderr --checkpoint_dir=training_mnet --run_once
# Out:
# 2021-03-02 02:02:03.539368: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0302 02:03:05.706080 140026824353664 model_lib_v2.py:1043] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0302 02:03:05.706383 140026824353664 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0302 02:03:05.706476 140026824353664 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0302 02:03:05.706567 140026824353664 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...

# %% [markdown]
# # Export Inference Graph

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path training_mnet/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.config --trained_checkpoint_dir training_mnet/model.ckpt-6 --output_directory fine_tuned_model
# Out:
# 2021-03-02 08:29:37.290807: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-02 08:29:39.643988: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 08:29:39.644793: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-02 08:29:39.673518: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-02 08:29:39.674086: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...
