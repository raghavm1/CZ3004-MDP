# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
## For first time, unzip object_detection folder to Tf2 folder
# !unzip '/content/gdrive/MyDrive/Tf2/object_detection.zip' -d '/content/gdrive/MyDrive/Tf2/'

# %% [markdown]
# # Install Libraries

# %%
# !pip install tf-models-official &> /dev/null
# !pip install tf_slim &> /dev/null
# !pip install lvis &> /dev/null
# &> /dev/null to hide output

# %%
# %cd '/content/gdrive/MyDrive/Tf2/object_detection'
# Out:
# /content/gdrive/.shortcut-targets-by-id/1jaHq3YfC0fjf8XaQtuFron75cotoj9Fe/Tf2/object_detection

# %%
# !protoc protos/*.proto --python_out=.
# Out:
# object_detection/protos/calibration.proto: "object_detection.protos.CalibrationConfig.calibrator" is already defined in file "protos/calibration.proto".
# object_detection/protos/calibration.proto:14:27: "object_detection.protos.CalibrationConfig.function_approximation" is already defined in file "protos/calibration.proto".
# object_detection/protos/calibration.proto:17:35: "object_detection.protos.CalibrationConfig.class_id_function_approximations" is already defined in file "protos/calibration.proto".
# object_detection/protos/calibration.proto:20:24: "object_detection.protos.CalibrationConfig.sigmoid_calibration" is already defined in file "protos/calibration.proto".
# object_detection/protos/calibration.proto:23:32: "object_detection.protos.CalibrationConfig.class_id_sigmoid_calibrations" is already defined in file "protos/calibration.proto".
# ...

# %% [markdown]
# # Train Model

# %%
# !python model_main_tf2.py --pipeline_config_path=training_ed_v2/ssd_efficientdet_d0_512x512_coco17_tpu-8.config --model_dir=training_ed_v2 --alsologtostderr
# Out:
# 2021-03-01 06:49:17.192550: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-01 06:49:20.118083: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-01 06:49:20.118981: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-01 06:49:20.134230: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-01 06:49:20.134870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...

# %% [markdown]
# # Generate inference graph

# %%
# !python exporter_main_v2.py --trained_checkpoint_dir=training_ed_v2 --pipeline_config_path=training_ed_v2/ssd_efficientdet_d0_512x512_coco17_tpu-8.config --output_directory inference_graph_ed_v2
# Out:
# 2021-03-01 07:22:28.814390: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-01 07:22:32.431161: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-01 07:22:32.433860: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-01 07:22:32.450570: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-01 07:22:32.451138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...

# %% [markdown]
# # Evaluate Model

# %%
# !python model_main_tf2.py --pipeline_config_path=training_ed_v2/ssd_efficientdet_d0_512x512_coco17_tpu-8.config --model_dir=training_ed_v2 --alsologtostderr --checkpoint_dir=training_ed_v2
# Out:
# 2021-03-01 07:25:40.456373: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0301 07:25:43.537343 140393454954368 model_lib_v2.py:1043] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0301 07:25:43.537578 140393454954368 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0301 07:25:43.537674 140393454954368 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0301 07:25:43.537770 140393454954368 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...
